# %% [markdown]
# # `Matplotlib` Basics:

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Creating two sample vectors.

#linspace creates an equally spaced starting from 1 to 100 and make 10 equally spaced.
x = np.linspace(start = 1, stop = 100, num = 10)
x
# Out:
# array([  1.,  12.,  23.,  34.,  45.,  56.,  67.,  78.,  89., 100.])

# %%
y = x ** 3 
y
# Out:
# array([1.00000e+00, 1.72800e+03, 1.21670e+04, 3.93040e+04, 9.11250e+04,
#        1.75616e+05, 3.00763e+05, 4.74552e+05, 7.04969e+05, 1.00000e+06])

# %% [markdown]
# ## 1. `Basics` of `Plotting`

# %%
plt.plot(x,y)

plt.title("X vs Y")

plt.xlabel("X axis ———————>")

plt.ylabel("Y axis ———————>")
# Out:
# Text(0, 0.5, 'Y axis ———————>')

# %% [markdown]
# ## 2. `Subplots` 🪟:
# * ### Subplots are basically divisons in the canvas
# * ### Subplot method has 3 parameters:
# * ### First two parameters are the the size/shape of the canvas i.e. How many division you need(2x2=4 divisions, 2x3=6 divisions)?
# * ### Last parameter is need to access the particular subplot.

# %%
plt.subplot(2, 2, 1)
plt.plot(x**3 ,y)

plt.subplot(2, 2, 2)
plt.plot(x*2, y)

plt.subplot(2, 2, 3)
plt.plot(x/2, y)

plt.subplot(2, 2, 4)
plt.plot(x, y/69420)

# %% [markdown]
# ## Custom subplots:
# * ### Matplotlib allows us to change the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
# * ### figsize is a tuple of the width and height of the figure in inches
# * ### dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize = (20, 8), dpi = 100)

"""
rect= [other axis width, other axis height, axis width, axis ]
"""
axis1 = fig.add_axes(rect = [0.1, -0.1, 0.2, 0.4])
axis1.plot(x, y)

axis2 = fig.add_axes(rect = [0.1, 0.4, 0.2, 0.4])
axis2.plot(y, x)

# %% [markdown]
# # **Some basic plots**:
# ## 1. `Scatter plot`

# %%
plt.scatter(x,y)

# %% [markdown]
# ## 2. `Histogram plot`

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(x = data, bins = 10, color = 'orange')
plt.xlabel(xlabel = "Numbers ———————>")
plt.ylabel(ylabel = "Frequency ———————>")
# Out:
# Text(0, 0.5, 'Frequency ———————>')

# %% [markdown]
# ## 3. `Box plot`

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8ad365c1a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8ad365c440>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8ad365c050>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8ad365c6e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8ad365c830>],
#  'means': []}

# %% [markdown]
# ## 4. Bar-plots

# %%
plt.bar(x = x, height = 1)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(y = x, width = 1)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 5. Pie Chart

# %%
df = pd.Series(data = {'True' : 350,
                        'False' : 450})

plt.pie(x = df, labels = df.index, autopct='%1.1f%%', shadow = True)
plt.legend()

# %% [markdown]
# ## **Saving Plots** as **Image**

# %%
fig = plt.figure()

ax = fig.add_axes(rect = [0.1, 0.1, 0.8, 0.8])

ax.plot(x,y)

plt.savefig('basicplot.png')

# %% [markdown]
# ## Working with Images:

# %%
import matplotlib.image as mpimg

# %%
#Read the image
img = mpimg.imread('Bell-Curve.webp')

#To show the image
plt.imshow(img)

#toggle axis on/off
plt.axis('on')
# Out:
# (np.float64(-0.5), np.float64(2799.5), np.float64(2099.5), np.float64(-0.5))

# %%
# crop: rows 800-1800, cols 750-2000
cropped_img = img[900: 2050, 733: 2030]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1296.5), np.float64(1149.5), np.float64(-0.5))

# %% [markdown]
# # `Plot Designing` (OPTIONAL):

# %%
plt.plot(x, y, color = "pink")

# %%
x_axis = np.linspace(0, 5, 11)
x_axis
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %% [markdown]
# * # Some `Samples` Of `Plot Design`:

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x_axis, x_axis+1, color="red", linewidth=0.25)
ax.plot(x_axis, x_axis+2, color="red", linewidth=0.50)
ax.plot(x_axis, x_axis+3, color="red", linewidth=1.00)
ax.plot(x_axis, x_axis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x_axis, x_axis+5, color="green", lw=3, linestyle='-')
ax.plot(x_axis, x_axis+6, color="green", lw=3, ls='-.')
ax.plot(x_axis, x_axis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x_axis, x_axis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x_axis, x_axis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x_axis, x_axis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x_axis, x_axis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x_axis, x_axis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(x_axis, x_axis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x_axis, x_axis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x_axis, x_axis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x_axis, x_axis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
